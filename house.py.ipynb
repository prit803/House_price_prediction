# %%
import pandas as pd
df=pd.read_csv('Housing.csv')
df
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
#     hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0                no             yes        2      yes        furnished
# 1                no             yes        3       no        furnished
# 2                no              no        2      yes   semi-furnished
# 3                no             yes        3      yes        furnished
# 4                no             yes        2       no        furnished
# ..              ...             ...      ...      ...              ...
# 540              no              no        2       no      unfurnished
# 541              no              no        0       no   semi-furnished
# 542              no              no        0       no      unfurnished
# 543              no              no        0       no        furnished
# 544              no              no        0       no      unfurnished
#
# [545 rows x 13 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             545 non-null    int64
#  1   area              545 non-null    int64
#  2   bedrooms          545 non-null    int64
#  3   bathrooms         545 non-null    int64
#  4   stories           545 non-null    int64
#  5   mainroad          545 non-null    object
#  6   guestroom         545 non-null    object
#  7   basement          545 non-null    object
#  8   hotwaterheating   545 non-null    object
#  9   airconditioning   545 non-null    object
#  10  parking           545 non-null    int64
#  11  prefarea          545 non-null    object
#  12  furnishingstatus  545 non-null    object
# dtypes: int64(6), object(7)
# memory usage: 55.5+ KB

# %%
df=pd.get_dummies(df,columns=['mainroad','guestroom','basement','hotwaterheating','airconditioning','prefarea','furnishingstatus'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 21 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   price                            545 non-null    int64
#  1   area                             545 non-null    int64
#  2   bedrooms                         545 non-null    int64
#  3   bathrooms                        545 non-null    int64
#  4   stories                          545 non-null    int64
#  5   parking                          545 non-null    int64
#  6   mainroad_no                      545 non-null    uint8
#  7   mainroad_yes                     545 non-null    uint8
#  8   guestroom_no                     545 non-null    uint8
#  9   guestroom_yes                    545 non-null    uint8
#  10  basement_no                      545 non-null    uint8
#  11  basement_yes                     545 non-null    uint8
#  12  hotwaterheating_no               545 non-null    uint8
#  13  hotwaterheating_yes              545 non-null    uint8
#  14  airconditioning_no               545 non-null    uint8
#  15  airconditioning_yes              545 non-null    uint8
#  16  prefarea_no                      545 non-null    uint8
#  17  prefarea_yes                     545 non-null    uint8
#  18  furnishingstatus_furnished       545 non-null    uint8
#  19  furnishingstatus_semi-furnished  545 non-null    uint8
#  20  furnishingstatus_unfurnished     545 non-null    uint8
# dtypes: int64(6), uint8(15)
# memory usage: 33.7 KB

# %%
df
# Out:
#         price  area  bedrooms  bathrooms  stories  parking  mainroad_no  \
# 0    13300000  7420         4          2        3        2            0
# 1    12250000  8960         4          4        4        3            0
# 2    12250000  9960         3          2        2        2            0
# 3    12215000  7500         4          2        2        3            0
# 4    11410000  7420         4          1        2        2            0
# ..        ...   ...       ...        ...      ...      ...          ...
# 540   1820000  3000         2          1        1        2            0
# 541   1767150  2400         3          1        1        0            1
# 542   1750000  3620         2          1        1        0            0
# 543   1750000  2910         3          1        1        0            1
# 544   1750000  3850         3          1        2        0            0
#
#      mainroad_yes  guestroom_no  guestroom_yes  ...  basement_yes  \
# 0               1             1              0  ...             0
# 1               1             1              0  ...             0
# 2               1             1              0  ...             1
# 3               1             1              0  ...             1
# 4               1             0              1  ...             1
# ..            ...           ...            ...  ...           ...
# 540             1             1              0  ...             1
# 541             0             1              0  ...             0
# 542             1             1              0  ...             0
# 543             0             1              0  ...             0
# 544             1             1              0  ...             0
#
#      hotwaterheating_no  hotwaterheating_yes  airconditioning_no  \
# 0                     1                    0                   0
# 1                     1                    0                   0
# 2                     1                    0                   1
# 3                     1                    0                   0
# 4                     1                    0                   0
# ..                  ...                  ...                 ...
# 540                   1                    0                   1
# 541                   1                    0                   1
# 542                   1                    0                   1
# 543                   1                    0                   1
# 544                   1                    0                   1
#
#      airconditioning_yes  prefarea_no  prefarea_yes  \
# 0                      1            0             1
# 1                      1            1             0
# 2                      0            0             1
# 3                      1            0             1
# 4                      1            1             0
# ..                   ...          ...           ...
# 540                    0            1             0
# 541                    0            1             0
# 542                    0            1             0
# 543                    0            1             0
# 544                    0            1             0
#
#      furnishingstatus_furnished  furnishingstatus_semi-furnished  \
# 0                             1                                0
# 1                             1                                0
# 2                             0                                1
# 3                             1                                0
# 4                             1                                0
# ..                          ...                              ...
# 540                           0                                0
# 541                           0                                1
# 542                           0                                0
# 543                           1                                0
# 544                           0                                0
#
#      furnishingstatus_unfurnished
# 0                               0
# 1                               0
# 2                               0
# 3                               0
# 4                               0
# ..                            ...
# 540                             1
# 541                             0
# 542                             1
# 543                             0
# 544                             1
#
# [545 rows x 21 columns]

# %%
df.corr()
# Out:
#                                     price      area  bedrooms  bathrooms  \
# price                            1.000000  0.535997  0.366494   0.517545
# area                             0.535997  1.000000  0.151858   0.193820
# bedrooms                         0.366494  0.151858  1.000000   0.373930
# bathrooms                        0.517545  0.193820  0.373930   1.000000
# stories                          0.420712  0.083996  0.408564   0.326165
# parking                          0.384394  0.352980  0.139270   0.177496
# mainroad_no                     -0.296898 -0.288874  0.012033  -0.042398
# mainroad_yes                     0.296898  0.288874 -0.012033   0.042398
# guestroom_no                    -0.255517 -0.140297 -0.080549  -0.126469
# guestroom_yes                    0.255517  0.140297  0.080549   0.126469
# basement_no                     -0.187057 -0.047417 -0.097312  -0.102106
# basement_yes                     0.187057  0.047417  0.097312   0.102106
# hotwaterheating_no              -0.093073  0.009229 -0.046049  -0.067159
# hotwaterheating_yes              0.093073 -0.009229  0.046049   0.067159
# airconditioning_no              -0.452954 -0.222393 -0.160603  -0.186915
# airconditioning_yes              0.452954  0.222393  0.160603   0.186915
# prefarea_no                     -0.329777 -0.234779 -0.079023  -0.063472
# prefarea_yes                     0.329777  0.234779  0.079023   0.063472
# furnishingstatus_furnished       0.229350  0.145772  0.079054   0.108139
# furnishingstatus_semi-furnished  0.063656  0.006156  0.050040   0.029834
# furnishingstatus_unfurnished    -0.280587 -0.142278 -0.126252  -0.132107
#
#                                   stories   parking  mainroad_no  \
# price                            0.420712  0.384394    -0.296898
# area                             0.083996  0.352980    -0.288874
# bedrooms                         0.408564  0.139270     0.012033
# bathrooms                        0.326165  0.177496    -0.042398
# stories                          1.000000  0.045547    -0.121706
# parking                          0.045547  1.000000    -0.204433
# mainroad_no                     -0.121706 -0.204433     1.000000
# mainroad_yes                     0.121706  0.204433    -1.000000
# guestroom_no                    -0.043538 -0.037466     0.092337
# guestroom_yes                    0.043538  0.037466    -0.092337
# basement_no                      0.172394 -0.051497     0.044002
# basement_yes                    -0.172394  0.051497    -0.044002
# hotwaterheating_no              -0.018847 -0.067864    -0.011781
# hotwaterheating_yes              0.018847  0.067864     0.011781
# airconditioning_no              -0.293602 -0.159173     0.105423
# airconditioning_yes              0.293602  0.159173    -0.105423
# prefarea_no                     -0.044425 -0.091627     0.199876
# prefarea_yes                     0.044425  0.091627    -0.199876
# furnishingstatus_furnished       0.093176  0.131234    -0.129971
# furnishingstatus_semi-furnished -0.003648  0.041327    -0.011450
# furnishingstatus_unfurnished    -0.082972 -0.165705     0.133123
#
#                                  mainroad_yes  guestroom_no  guestroom_yes  \
# price                                0.296898     -0.255517       0.255517
# area                                 0.288874     -0.140297       0.140297
# bedrooms                            -0.012033     -0.080549       0.080549
# bathrooms                            0.042398     -0.126469       0.126469
# stories                              0.121706     -0.043538       0.043538
# parking                              0.204433     -0.037466       0.037466
# mainroad_no                         -1.000000      0.092337      -0.092337
# mainroad_yes                         1.000000     -0.092337       0.092337
# guestroom_no                        -0.092337      1.000000      -1.000000
# guestroom_yes                        0.092337     -1.000000       1.000000
# basement_no                         -0.044002      0.372066      -0.372066
# basement_yes                         0.044002     -0.372066       0.372066
# hotwaterheating_no                   0.011781     -0.010308       0.010308
# hotwaterheating_yes                 -0.011781      0.010308      -0.010308
# airconditioning_no                  -0.105423      0.138179      -0.138179
# airconditioning_yes                  0.105423     -0.138179       0.138179
# prefarea_no                         -0.199876      0.160897      -0.160897
# prefarea_yes                         0.199876     -0.160897       0.160897
# furnishingstatus_furnished           0.129971     -0.099721       0.099721
# furnishingstatus_semi-furnished      0.011450     -0.005821       0.005821
# furnishingstatus_unfurnished        -0.133123      0.099023      -0.099023
#
#                                  ...  basement_yes  hotwaterheating_no  \
# price                            ...      0.187057           -0.093073
# area                             ...      0.047417            0.009229
# bedrooms                         ...      0.097312           -0.046049
# bathrooms                        ...      0.102106           -0.067159
# stories                          ...     -0.172394           -0.018847
# parking                          ...      0.051497           -0.067864
# mainroad_no                      ...     -0.044002           -0.011781
# mainroad_yes                     ...      0.044002            0.011781
# guestroom_no                     ...     -0.372066           -0.010308
# guestroom_yes                    ...      0.372066            0.010308
# basement_no                      ...     -1.000000            0.004385
# basement_yes                     ...      1.000000           -0.004385
# hotwaterheating_no               ...     -0.004385            1.000000
# hotwaterheating_yes              ...      0.004385           -1.000000
# airconditioning_no               ...     -0.047341           -0.130023
# airconditioning_yes              ...      0.047341            0.130023
# prefarea_no                      ...     -0.228083           -0.059411
# prefarea_yes                     ...      0.228083            0.059411
# furnishingstatus_furnished       ...      0.069852            0.008472
# furnishingstatus_semi-furnished  ...      0.050284           -0.063819
# furnishingstatus_unfurnished     ...     -0.117935            0.059194
#
#                                  hotwaterheating_yes  airconditioning_no  \
# price                                       0.093073           -0.452954
# area                                       -0.009229           -0.222393
# bedrooms                                    0.046049           -0.160603
# bathrooms                                   0.067159           -0.186915
# stories                                     0.018847           -0.293602
# parking                                     0.067864           -0.159173
# mainroad_no                                 0.011781            0.105423
# mainroad_yes                               -0.011781           -0.105423
# guestroom_no                                0.010308            0.138179
# guestroom_yes                              -0.010308           -0.138179
# basement_no                                -0.004385            0.047341
# basement_yes                                0.004385           -0.047341
# hotwaterheating_no                         -1.000000           -0.130023
# hotwaterheating_yes                         1.000000            0.130023
# airconditioning_no                          0.130023            1.000000
# airconditioning_yes                        -0.130023           -1.000000
# prefarea_no                                 0.059411            0.117382
# prefarea_yes                               -0.059411           -0.117382
# furnishingstatus_furnished                 -0.008472           -0.160994
# furnishingstatus_semi-furnished             0.063819            0.053179
# furnishingstatus_unfurnished               -0.059194            0.094086
#
#                                  airconditioning_yes  prefarea_no  \
# price                                       0.452954    -0.329777
# area                                        0.222393    -0.234779
# bedrooms                                    0.160603    -0.079023
# bathrooms                                   0.186915    -0.063472
# stories                                     0.293602    -0.044425
# parking                                     0.159173    -0.091627
# mainroad_no                                -0.105423     0.199876
# mainroad_yes                                0.105423    -0.199876
# guestroom_no                               -0.138179     0.160897
# guestroom_yes                               0.138179    -0.160897
# basement_no                                -0.047341     0.228083
# basement_yes                                0.047341    -0.228083
# hotwaterheating_no                          0.130023    -0.059411
# hotwaterheating_yes                        -0.130023     0.059411
# airconditioning_no                         -1.000000     0.117382
# airconditioning_yes                         1.000000    -0.117382
# prefarea_no                                -0.117382     1.000000
# prefarea_yes                                0.117382    -1.000000
# furnishingstatus_furnished                  0.160994    -0.100249
# furnishingstatus_semi-furnished            -0.053179     0.011535
# furnishingstatus_unfurnished               -0.094086     0.081271
#
#                                  prefarea_yes  furnishingstatus_furnished  \
# price                                0.329777                    0.229350
# area                                 0.234779                    0.145772
# bedrooms                             0.079023                    0.079054
# bathrooms                            0.063472                    0.108139
# stories                              0.044425                    0.093176
# parking                              0.091627                    0.131234
# mainroad_no                         -0.199876                   -0.129971
# mainroad_yes                         0.199876                    0.129971
# guestroom_no                        -0.160897                   -0.099721
# guestroom_yes                        0.160897                    0.099721
# basement_no                         -0.228083                   -0.069852
# basement_yes                         0.228083                    0.069852
# hotwaterheating_no                   0.059411                    0.008472
# hotwaterheating_yes                 -0.059411                   -0.008472
# airconditioning_no                  -0.117382                   -0.160994
# airconditioning_yes                  0.117382                    0.160994
# prefarea_no                         -1.000000                   -0.100249
# prefarea_yes                         1.000000                    0.100249
# furnishingstatus_furnished           0.100249                    1.000000
# furnishingstatus_semi-furnished     -0.011535                   -0.496748
# furnishingstatus_unfurnished        -0.081271                   -0.409462
#
#                                  furnishingstatus_semi-furnished  \
# price                                                   0.063656
# area                                                    0.006156
# bedrooms                                                0.050040
# bathrooms                                               0.029834
# stories                                                -0.003648
# parking                                                 0.041327
# mainroad_no                                            -0.011450
# mainroad_yes                                            0.011450
# guestroom_no                                           -0.005821
# guestroom_yes                                           0.005821
# basement_no                                            -0.050284
# basement_yes                                            0.050284
# hotwaterheating_no                                     -0.063819
# hotwaterheating_yes                                     0.063819
# airconditioning_no                                      0.053179
# airconditioning_yes                                    -0.053179
# prefarea_no                                             0.011535
# prefarea_yes                                           -0.011535
# furnishingstatus_furnished                             -0.496748
# furnishingstatus_semi-furnished                         1.000000
# furnishingstatus_unfurnished                           -0.588405
#
#                                  furnishingstatus_unfurnished
# price                                               -0.280587
# area                                                -0.142278
# bedrooms                                            -0.126252
# bathrooms                                           -0.132107
# stories                                             -0.082972
# parking                                             -0.165705
# mainroad_no                                          0.133123
# mainroad_yes                                        -0.133123
# guestroom_no                                         0.099023
# guestroom_yes                                       -0.099023
# basement_no                                          0.117935
# basement_yes                                        -0.117935
# hotwaterheating_no                                   0.059194
# hotwaterheating_yes                                 -0.059194
# airconditioning_no                                   0.094086
# airconditioning_yes                                 -0.094086
# prefarea_no                                          0.081271
# prefarea_yes                                        -0.081271
# furnishingstatus_furnished                          -0.409462
# furnishingstatus_semi-furnished                     -0.588405
# furnishingstatus_unfurnished                         1.000000
#
# [21 rows x 21 columns]

# %%
import matplotlib.pyplot as plt
pd.plotting.scatter_matrix(df,figsize=(20,20))
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

x=df.drop('price',axis=1)
y=df['price']

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
model=LinearRegression()
model.fit(x_train,y_train)
#now we predict the value.

y_pred=model.predict(x_test)

# %%
print("co-efficient:",model.coef_)
#coefficient
print("intercept:",model.intercept_)
#intercept of model
# Out:
# co-efficient: [ 2.35968805e+02  7.67787016e+04  1.09444479e+06  4.07476595e+05
#   2.24841913e+05 -1.83959974e+05  1.83959974e+05 -1.15805019e+05
#   1.15805019e+05 -1.95125588e+05  1.95125588e+05 -3.42324943e+05
#   3.42324943e+05 -3.95713368e+05  3.95713368e+05 -3.14945283e+05
#   3.14945283e+05  1.80175627e+05  5.32938090e+04 -2.33469436e+05]
# intercept: 1627730.9047687845

# %%
print("mean sqaured error :",mean_squared_error(y_test,y_pred))
# Out:
# mean sqaured error : 1754318687330.6602

# %%
print("mean absolute error :",mean_absolute_error(y_test,y_pred))
# Out:
# mean absolute error : 970043.4039201635

# %%
print("r2 score :",r2_score(y_test,y_pred))
# Out:
# r2 score : 0.6529242642153191
